# %%
import numpy as np 
from qiskit.quantum_info import Statevector

# %%
θ = np.pi/3
φ =  - np.pi/6

q0 = np.cos(θ/2)
q1 = np.exp(1j*φ)*np.sin(θ/2)

# %%
q = Statevector([q0 , q1])
q.draw('bloch')

# %%
q.draw('latex')
# Out:
# $$\frac{\sqrt{3}}{2} |0\rangle+(\frac{\sqrt{3}}{4} - \frac{i}{4}) |1\rangle$$

# %%
# Out:
# 'jt' is not recognized as an internal or external command,
# operable program or batch file.
